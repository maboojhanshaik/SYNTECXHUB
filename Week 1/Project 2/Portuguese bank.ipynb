# %% [markdown]
# Importing the required packages

# %%
import pandas as pd

# %% [markdown]
# Reading the CSV File

# %%
raw_data=pd.read_csv("bank-additional/bank-additional/bank.csv",sep=';')

# %% [markdown]
# Exploring the data

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4119 entries, 0 to 4118
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             4119 non-null   int64
#  1   job             4119 non-null   object
#  2   marital         4119 non-null   object
#  3   education       4119 non-null   object
#  4   default         4119 non-null   object
#  5   housing         4119 non-null   object
#  6   loan            4119 non-null   object
#  7   contact         4119 non-null   object
#  8   month           4119 non-null   object
#  9   day_of_week     4119 non-null   object
#  10  duration        4119 non-null   int64
#  11  campaign        4119 non-null   int64
#  12  pdays           4119 non-null   int64
#  13  previous        4119 non-null   int64
#  14  poutcome        4119 non-null   object
#  15  emp.var.rate    4119 non-null   float64
#  16  cons.price.idx  4119 non-null   float64
#  17  cons.conf.idx   4119 non-null   float64
#  18  euribor3m       4119 non-null   float64
#  19  nr.employed     4119 non-null   float64
#  20  y               4119 non-null   object
# dtypes: float64(5), int64(5), object(11)
# memory usage: 675.9+ KB

# %%
raw_data.dtypes
# Out:
# age                 int64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# duration            int64
# campaign            int64
# pdays               int64
# previous            int64
# poutcome           object
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# nr.employed       float64
# y                  object
# dtype: object

# %%
raw_data.head()
# Out:
#    age          job  marital          education default  housing     loan  \
# 0   30  blue-collar  married           basic.9y      no      yes       no
# 1   39     services   single        high.school      no       no       no
# 2   25     services  married        high.school      no      yes       no
# 3   38     services  married           basic.9y      no  unknown  unknown
# 4   47       admin.  married  university.degree      no      yes       no
#
#      contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0   cellular   may         fri  ...         2    999         0  nonexistent
# 1  telephone   may         fri  ...         4    999         0  nonexistent
# 2  telephone   jun         wed  ...         1    999         0  nonexistent
# 3  telephone   jun         fri  ...         3    999         0  nonexistent
# 4   cellular   nov         mon  ...         1    999         0  nonexistent
#
#   emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0         -1.8          92.893          -46.2      1.313       5099.1  no
# 1          1.1          93.994          -36.4      4.855       5191.0  no
# 2          1.4          94.465          -41.8      4.962       5228.1  no
# 3          1.4          94.465          -41.8      4.959       5228.1  no
# 4         -0.1          93.200          -42.0      4.191       5195.8  no
#
# [5 rows x 21 columns]

# %%
raw_data.tail()
# Out:
#       age         job  marital    education default housing loan    contact  \
# 4114   30      admin.  married     basic.6y      no     yes  yes   cellular
# 4115   39      admin.  married  high.school      no     yes   no  telephone
# 4116   27     student   single  high.school      no      no   no   cellular
# 4117   58      admin.  married  high.school      no      no   no   cellular
# 4118   34  management   single  high.school      no     yes   no   cellular
#
#      month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 4114   jul         thu  ...         1    999         0  nonexistent
# 4115   jul         fri  ...         1    999         0  nonexistent
# 4116   may         mon  ...         2    999         1      failure
# 4117   aug         fri  ...         1    999         0  nonexistent
# 4118   nov         wed  ...         1    999         0  nonexistent
#
#      emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 4114          1.4          93.918          -42.7      4.958       5228.1  no
# 4115          1.4          93.918          -42.7      4.959       5228.1  no
# 4116         -1.8          92.893          -46.2      1.354       5099.1  no
# 4117          1.4          93.444          -36.1      4.966       5228.1  no
# 4118         -0.1          93.200          -42.0      4.120       5195.8  no
#
# [5 rows x 21 columns]

# %%
raw_data.describe()
# Out:
#                age     duration     campaign        pdays     previous  \
# count  4119.000000  4119.000000  4119.000000  4119.000000  4119.000000
# mean     40.113620   256.788055     2.537266   960.422190     0.190337
# std      10.313362   254.703736     2.568159   191.922786     0.541788
# min      18.000000     0.000000     1.000000     0.000000     0.000000
# 25%      32.000000   103.000000     1.000000   999.000000     0.000000
# 50%      38.000000   181.000000     2.000000   999.000000     0.000000
# 75%      47.000000   317.000000     3.000000   999.000000     0.000000
# max      88.000000  3643.000000    35.000000   999.000000     6.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx    euribor3m  nr.employed
# count   4119.000000     4119.000000    4119.000000  4119.000000  4119.000000
# mean       0.084972       93.579704     -40.499102     3.621356  5166.481695
# std        1.563114        0.579349       4.594578     1.733591    73.667904
# min       -3.400000       92.201000     -50.800000     0.635000  4963.600000
# 25%       -1.800000       93.075000     -42.700000     1.334000  5099.100000
# 50%        1.100000       93.749000     -41.800000     4.857000  5191.000000
# 75%        1.400000       93.994000     -36.400000     4.961000  5228.100000
# max        1.400000       94.767000     -26.900000     5.045000  5228.100000

# %% [markdown]
# Filtering the data based on age criteria i.e age>=50

# %%
age50=raw_data[raw_data['age']>=50].reset_index(drop=True)
age50.index=age50.index+1
age50.head()
# Out:
#    age          job  marital          education  default housing loan  \
# 1   50  blue-collar  married           basic.4y       no      no  yes
# 2   55     services  married           basic.6y  unknown     yes   no
# 3   51   technician   single  university.degree       no      no   no
# 4   76      retired  married  university.degree       no      no   no
# 5   56      retired  married  university.degree       no     yes   no
#
#     contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 1  cellular   jul         tue  ...         1    999         0  nonexistent
# 2  cellular   jul         tue  ...         6    999         0  nonexistent
# 3  cellular   jun         fri  ...         2    999         0  nonexistent
# 4  cellular   aug         thu  ...         1    999         1      failure
# 5  cellular   jun         wed  ...         1    999         2      failure
#
#   emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed    y
# 1          1.4          93.918          -42.7      4.961       5228.1  yes
# 2          1.4          93.918          -42.7      4.962       5228.1   no
# 3         -2.9          92.963          -40.8      1.268       5076.2   no
# 4         -1.7          94.027          -38.3      0.899       4991.6   no
# 5         -2.9          92.963          -40.8      1.260       5076.2   no
#
# [5 rows x 21 columns]

# %% [markdown]
# Filtering the consumers having house loan

# %%
house_loan_status_yes =raw_data[raw_data['housing']=='yes'].reset_index(drop=True)
house_loan_status_yes.index=house_loan_status_yes.index+1
house_loan_status_yes.head()
# Out:
#    age           job  marital          education  default housing loan  \
# 1   30   blue-collar  married           basic.9y       no     yes   no
# 2   25      services  married        high.school       no     yes   no
# 3   47        admin.  married  university.degree       no     yes   no
# 4   32        admin.   single  university.degree       no     yes   no
# 5   41  entrepreneur  married  university.degree  unknown     yes   no
#
#      contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 1   cellular   may         fri  ...         2    999         0  nonexistent
# 2  telephone   jun         wed  ...         1    999         0  nonexistent
# 3   cellular   nov         mon  ...         1    999         0  nonexistent
# 4   cellular   sep         mon  ...         4    999         0  nonexistent
# 5   cellular   nov         mon  ...         2    999         0  nonexistent
#
#   emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 1         -1.8          92.893          -46.2      1.313       5099.1  no
# 2          1.4          94.465          -41.8      4.962       5228.1  no
# 3         -0.1          93.200          -42.0      4.191       5195.8  no
# 4         -1.1          94.199          -37.5      0.879       4963.6  no
# 5         -0.1          93.200          -42.0      4.191       5195.8  no
#
# [5 rows x 21 columns]

# %% [markdown]
# Filtering High campaign contacts (>5)

# %%
high_campaign =raw_data[raw_data['campaign']>5].reset_index(drop=True)
high_campaign.index=high_campaign.index+1
high_campaign.head()
# Out:
#    age         job   marital            education  default housing loan  \
# 1   44      admin.  divorced    university.degree       no      no   no
# 2   55    services   married             basic.6y  unknown     yes   no
# 3   44  technician   married  professional.course  unknown     yes   no
# 4   48  technician   married    university.degree       no      no   no
# 5   29      admin.    single    university.degree       no     yes   no
#
#      contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 1   cellular   jul         wed  ...         6    999         0  nonexistent
# 2   cellular   jul         tue  ...         6    999         0  nonexistent
# 3  telephone   may         fri  ...         7    999         0  nonexistent
# 4   cellular   aug         thu  ...         7    999         0  nonexistent
# 5  telephone   jun         fri  ...        27    999         0  nonexistent
#
#   emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 1          1.4          93.918          -42.7      4.957       5228.1  no
# 2          1.4          93.918          -42.7      4.962       5228.1  no
# 3          1.1          93.994          -36.4      4.864       5191.0  no
# 4          1.4          93.444          -36.1      4.962       5228.1  no
# 5          1.4          94.465          -41.8      4.959       5228.1  no
#
# [5 rows x 21 columns]

# %% [markdown]
# Selecting required colums

# %%
required_colums = raw_data[['age', 'job', 'loan', 'y']].reset_index(drop=True)
required_colums.index=required_colums.index+1
required_colums.head()
# Out:
#    age          job     loan   y
# 1   30  blue-collar       no  no
# 2   39     services       no  no
# 3   25     services       no  no
# 4   38     services  unknown  no
# 5   47       admin.       no  no

# %% [markdown]
# Taking subset of first 100 rows and 300 to 400 rows

# %%
first_100=raw_data.iloc[:100]
first_100.index=first_100.index+1
first_100
# Out:
#      age          job  marital            education  default  housing  \
# 1     30  blue-collar  married             basic.9y       no      yes
# 2     39     services   single          high.school       no       no
# 3     25     services  married          high.school       no      yes
# 4     38     services  married             basic.9y       no  unknown
# 5     47       admin.  married    university.degree       no      yes
# ..   ...          ...      ...                  ...      ...      ...
# 96    43   management  married  professional.course       no       no
# 97    58      retired  married             basic.6y  unknown       no
# 98    31   technician  married  professional.course       no      yes
# 99    53   management  married    university.degree       no       no
# 100   52       admin.  married              unknown       no       no
#
#         loan    contact month day_of_week  ...  campaign  pdays  previous  \
# 1         no   cellular   may         fri  ...         2    999         0
# 2         no  telephone   may         fri  ...         4    999         0
# 3         no  telephone   jun         wed  ...         1    999         0
# 4    unknown  telephone   jun         fri  ...         3    999         0
# 5         no   cellular   nov         mon  ...         1    999         0
# ..       ...        ...   ...         ...  ...       ...    ...       ...
# 96        no   cellular   nov         tue  ...         2    999         0
# 97        no  telephone   may         mon  ...         3    999         0
# 98        no  telephone   may         wed  ...         6    999         0
# 99        no   cellular   jul         tue  ...         2    999         0
# 100       no   cellular   aug         tue  ...         1    999         0
#
#         poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 1    nonexistent         -1.8          92.893          -46.2      1.313
# 2    nonexistent          1.1          93.994          -36.4      4.855
# 3    nonexistent          1.4          94.465          -41.8      4.962
# 4    nonexistent          1.4          94.465          -41.8      4.959
# 5    nonexistent         -0.1          93.200          -42.0      4.191
# ..           ...          ...             ...            ...        ...
# 96   nonexistent         -0.1          93.200          -42.0      4.153
# 97   nonexistent          1.1          93.994          -36.4      4.857
# 98   nonexistent          1.1          93.994          -36.4      4.856
# 99   nonexistent          1.4          93.918          -42.7      4.961
# 100  nonexistent          1.4          93.444          -36.1      4.968
#
#      nr.employed   y
# 1         5099.1  no
# 2         5191.0  no
# 3         5228.1  no
# 4         5228.1  no
# 5         5195.8  no
# ..           ...  ..
# 96        5195.8  no
# 97        5191.0  no
# 98        5191.0  no
# 99        5228.1  no
# 100       5228.1  no
#
# [100 rows x 21 columns]

# %%
rows_300_400=raw_data.iloc[300:400]
rows_300_400.index=rows_300_400.index+1
rows_300_400
# Out:
#      age            job   marital            education  default housing loan  \
# 301   33     technician   married  professional.course       no      no   no
# 302   56   entrepreneur   married    university.degree       no     yes  yes
# 303   57        retired   married             basic.9y       no      no   no
# 304   24         admin.    single          high.school  unknown     yes   no
# 305   39  self-employed   married    university.degree       no      no   no
# ..   ...            ...       ...                  ...      ...     ...  ...
# 396   30         admin.    single    university.degree       no      no   no
# 397   33    blue-collar   married             basic.9y       no     yes   no
# 398   37         admin.    single          high.school       no      no  yes
# 399   45  self-employed  divorced    university.degree       no      no  yes
# 400   30         admin.    single    university.degree       no      no   no
#
#        contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 301  telephone   may         thu  ...         4    999         0  nonexistent
# 302  telephone   jun         thu  ...         1    999         0  nonexistent
# 303   cellular   aug         tue  ...         4    999         0  nonexistent
# 304  telephone   jul         thu  ...         1    999         0  nonexistent
# 305  telephone   may         wed  ...         2    999         0  nonexistent
# ..         ...   ...         ...  ...       ...    ...       ...          ...
# 396   cellular   aug         mon  ...         1    999         0  nonexistent
# 397   cellular   jul         tue  ...         1    999         0  nonexistent
# 398   cellular   jul         tue  ...         6    999         0  nonexistent
# 399   cellular   may         fri  ...         1    999         0  nonexistent
# 400   cellular   nov         fri  ...         2    999         1      failure
#
#     emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed    y
# 301          1.1          93.994          -36.4      4.860       5191.0   no
# 302          1.4          94.465          -41.8      4.961       5228.1   no
# 303          1.4          93.444          -36.1      4.965       5228.1  yes
# 304          1.4          93.918          -42.7      4.958       5228.1   no
# 305          1.1          93.994          -36.4      4.858       5191.0   no
# ..           ...             ...            ...        ...          ...  ...
# 396          1.4          93.444          -36.1      4.965       5228.1   no
# 397          1.4          93.918          -42.7      4.961       5228.1   no
# 398          1.4          93.918          -42.7      4.961       5228.1   no
# 399         -1.8          92.893          -46.2      1.250       5099.1   no
# 400         -0.1          93.200          -42.0      4.021       5195.8   no
#
# [100 rows x 21 columns]

# %% [markdown]
# Saving the files

# %%
age50.to_csv("customers_above_50.csv", index=False)

# %%
age50.to_excel("customers_above_50.xlsx", index=False)
